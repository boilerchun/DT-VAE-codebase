# %%
import covid_cluster_preprocess as preprocess
import numpy as np
import DTP_score

# %%
preprocess.raw_data_loading(raw_data_dir='datasets/covid_county_original/county_data_MA3.npy', option='county')
# Out:
# ...
# Loading the raw data...
# Clustering the raw data...
# Saving the clustered data...
# Done!
# ...

# %%
preprocess.norm_and_split_train_test(data_dir='datasets/Dataset_Dynamic_Trend_Preserve/County/', data_name='decreasing', save_dir='datasets/Dataset_Dynamic_Trend_Preserve/County/train_test/')
preprocess.norm_and_split_train_test(data_dir='datasets/Dataset_Dynamic_Trend_Preserve/County/', data_name='increasing', save_dir='datasets/Dataset_Dynamic_Trend_Preserve/County/train_test/')
preprocess.norm_and_split_train_test(data_dir='datasets/Dataset_Dynamic_Trend_Preserve/County/', data_name='late_peak', save_dir='datasets/Dataset_Dynamic_Trend_Preserve/County/train_test/', train_ratio=0.5, weekly_norm_flag=True, option='county')
preprocess.norm_and_split_train_test(data_dir='datasets/Dataset_Dynamic_Trend_Preserve/County/', data_name='through', save_dir='datasets/Dataset_Dynamic_Trend_Preserve/County/train_test/')
# Out:
# ...
# Normalizing the clustered data...
# Splitting the data into training set and testing set...
# Done!
# ...
#
# ...
# Normalizing the clustered data...
# Splitting the data into training set and testing set...
# Done!
# ...
#
# ...
# Normalizing the clustered data...
# Splitting the data into training set and testing set...
# Done!
# ...
#
# ...
# Normalizing the clustered data...
# Splitting the data into training set and testing set...
# Done!
# ...

# %%
preprocess.shuffle_mix_data(data_name_list=['decreasing_train', 'late_peak_train'], save_dir='./datasets/Dataset_Dynamic_Trend_Preserve/County/train_test/', data_save_name='decreasing_late_peak_train')
preprocess.shuffle_mix_data(data_name_list=['decreasing_test', 'late_peak_test'], save_dir='./datasets/Dataset_Dynamic_Trend_Preserve/County/train_test/', data_save_name='decreasing_late_peak_test')

preprocess.shuffle_mix_data(data_name_list=['increasing_train', 'through_train'], save_dir='./datasets/Dataset_Dynamic_Trend_Preserve/County/train_test/', data_save_name='increasing_through_train')
preprocess.shuffle_mix_data(data_name_list=['increasing_test', 'through_test'], save_dir='./datasets/Dataset_Dynamic_Trend_Preserve/County/train_test/', data_save_name='increasing_through_test')

# %%
# !python3 run_dvae_gan.py --data_name county_decreasing_and_late_peak --experiment_name DT-VAE-GAN_county_decreasing_late_peak --parent_dir ./experiments --epochs 550 --lr 0.0011 --dis_recon_loss_weight 0.8 --ad_loss_weight 25 --recon_loss_weight 1 --data_dir ./datasets/Dataset_Dynamic_Trend_Preserve/County/train_test/ --hidden_dim 32 --d_layer 2 --noise_dim 15 --encoder_layer 3 --decoder_layer 3
# !python3 run_dvae_gan.py --data_name county_decreasing_and_late_peak --experiment_name DT-VAE-GAN_county_decreasing_late_peak --parent_dir ./experiments --epochs 500 --lr 0.001 --dis_recon_loss_weight 0.8 --ad_loss_weight 25 --recon_loss_weight 1 --data_dir ./datasets/Dataset_Dynamic_Trend_Preserve/County/train_test/ --hidden_dim 32 --d_layer 3 --noise_dim 15
# !python3 sample_path_generation.py --save_dir ./experiments/DT-VAE-GAN_county_decreasing_late_peak/DT-VAE-GAN_county_decreasing_late_peak.npy --dataset_dir ./datasets/Dataset_Dynamic_Trend_Preserve/County/train_test/ --dataset_name decreasing_late_peak_test.npy --model_dir ./experiments/DT-VAE-GAN_county_decreasing_late_peak/ --diff_first_day True --model_name vae_gan_trained_model --noise_dim 15 --device cuda:0
DTP_score.get_dtp_results(orig_c1_name='./datasets/Dataset_Dynamic_Trend_Preserve/County/train_test/decreasing_test.npy', orig_c2_name='./datasets/Dataset_Dynamic_Trend_Preserve/County/train_test/late_peak_test.npy', gen_mix_data='./experiments/DT-VAE-GAN_county_decreasing_late_peak/DT-VAE-GAN_county_decreasing_late_peak.npy', dim_option=0)
# Out:
# True
# True
# True
# True
# True
# True
# ...
# args:  Namespace(batch_size=50, encoder_layer=3, decoder_layer=3, d_layer=2, hidden_dim=32, noise_dim=15, dropout=0, opt='adam', seed=7777, data_dir='./datasets/Dataset_Dynamic_Trend_Preserve/County/train_test/', data_name='county_decreasing_and_late_peak', opt_scheduler='step', opt_decay_step=80, opt_decay_rate=0.8, weight_decay=0, lr=0.0011, epochs=555, ad_loss_weight=25, experiment_name='DT-VAE-GAN_county_decreasing_late_peak', parent_dir='./experiments', dis_recon_loss_weight=0.8, recon_loss_weight=1.0)
# ...
# [INFO] Using dataset: county_decreasing_and_late_peak, Using device: cuda:0, Using seed: 7777
# ...
# 0, reconstruction_loss: 307.3671 kl_div: 4.4649, bce loss: 97.1605
# 1, reconstruction_loss: 272.0503 kl_div: 2.4920, bce loss: 92.3691
# 2, reconstruction_loss: 216.7727 kl_div: 1.3139, bce loss: 90.2351
# 3, reconstruction_loss: 157.3379 kl_div: 0.6407, bce loss: 89.3360
# 4, reconstruction_loss: 123.8384 kl_div: 0.3418, bce loss: 87.6487
# ...

# %%
# !python3 sample_path_generation.py --save_dir ./experiments/DT-VAE-GAN_county_increasing_and_trough/DT-VAE-GAN_county_increasing_and_trough.npy --dataset_dir ./datasets/Dataset_Dynamic_Trend_Preserve/County/train_test/ --dataset_name increasing_through_test.npy --model_dir ./experiments/DT-VAE-GAN_county_increasing_and_trough/ --diff_first_day True --model_name vae_gan_trained_model --device cuda:0
DTP_score.get_dtp_results(orig_c1_name='./datasets/Dataset_Dynamic_Trend_Preserve/County/train_test/increasing_test.npy', orig_c2_name='./datasets/Dataset_Dynamic_Trend_Preserve/County/train_test/through_test.npy', gen_mix_data='./experiments/DT-VAE-GAN_county_increasing_and_trough/DT-VAE-GAN_county_increasing_and_trough.npy', dim_option=1)

# %%
# COVID-19 State-level

# %%
preprocess.raw_data_loading(raw_data_dir='datasets/covid_state_original/state_wide_covid_hospitalization.npy', option='state', random_state=27)
preprocess.norm_and_split_train_test(data_dir='datasets/Dataset_Dynamic_Trend_Preserve/State/', data_name='decreasing', save_dir='datasets/Dataset_Dynamic_Trend_Preserve/State/train_test/', option='state')
preprocess.norm_and_split_train_test(data_dir='datasets/Dataset_Dynamic_Trend_Preserve/State/', data_name='increasing', save_dir='datasets/Dataset_Dynamic_Trend_Preserve/State/train_test/', option='state')
preprocess.norm_and_split_train_test(data_dir='datasets/Dataset_Dynamic_Trend_Preserve/State/', data_name='late_peak', save_dir='datasets/Dataset_Dynamic_Trend_Preserve/State/train_test/', train_ratio=0.5, weekly_norm_flag=True, option='state')
preprocess.norm_and_split_train_test(data_dir='datasets/Dataset_Dynamic_Trend_Preserve/State/', data_name='early_peak', save_dir='datasets/Dataset_Dynamic_Trend_Preserve/State/train_test/', option='state')
preprocess.shuffle_mix_data(data_name_list=['decreasing_train', 'late_peak_train'], save_dir='./datasets/Dataset_Dynamic_Trend_Preserve/State/train_test/', data_save_name='decreasing_late_peak_train')
preprocess.shuffle_mix_data(data_name_list=['decreasing_test', 'late_peak_test'], save_dir='./datasets/Dataset_Dynamic_Trend_Preserve/State/train_test/', data_save_name='decreasing_late_peak_test')
preprocess.shuffle_mix_data(data_name_list=['increasing_train', 'early_peak_train'], save_dir='./datasets/Dataset_Dynamic_Trend_Preserve/State/train_test/', data_save_name='increasing_early_peak_train')
preprocess.shuffle_mix_data(data_name_list=['increasing_test', 'early_peak_test'], save_dir='./datasets/Dataset_Dynamic_Trend_Preserve/State/train_test/', data_save_name='increasing_early_peak_test')

# %%
# !python3 run_dvae_gan.py --data_name state_decreasing_and_late_peak --experiment_name DT-VAE-GAN_state_decreasing_late_peak --parent_dir ./experiments --epochs 1000 --lr 0.002 --dis_recon_loss_weight 0.1 --ad_loss_weight 5 --recon_loss_weight 1 --data_dir ./datasets/Dataset_Dynamic_Trend_Preserve/State/train_test/ --hidden_dim 32 --d_layer 3 --encoder_layer 3 --decoder_layer 4

# !python3 sample_path_generation.py --save_dir ./experiments/DT-VAE-GAN_state_decreasing_late_peak/DT-VAE-GAN_state_decreasing_late_peak.npy --dataset_dir ./datasets/Dataset_Dynamic_Trend_Preserve/State/train_test/ --dataset_name decreasing_late_peak_test.npy --model_dir ./experiments/DT-VAE-GAN_state_decreasing_late_peak/ --diff_first_day True --model_name vae_gan_trained_model --device cuda:0
DTP_score.get_dtp_results(orig_c1_name='./datasets/Dataset_Dynamic_Trend_Preserve/State/train_test/decreasing_test.npy', orig_c2_name='./datasets/Dataset_Dynamic_Trend_Preserve/State/train_test/late_peak_test.npy', gen_mix_data='./experiments/DT-VAE-GAN_state_decreasing_late_peak/DT-VAE-GAN_state_decreasing_late_peak.npy', dim_option=0)

# %%
# !python3 run_dvae_gan.py --data_name state_increasing_and_early_peak --experiment_name DT-VAE-GAN_state_increasing_early_peak --parent_dir ./experiments --epochs 1000 --lr 0.0015 --dis_recon_loss_weight 0.1 --ad_loss_weight 5 --recon_loss_weight 1 --data_dir ./datasets/Dataset_Dynamic_Trend_Preserve/State/train_test/ --hidden_dim 46 --d_layer 3 --encoder_layer 3 --decoder_layer 4

# !python3 sample_path_generation.py --save_dir ./experiments/DT-VAE-GAN_state_increasing_early_peak/DT-VAE-GAN_state_increasing_early_peak.npy --dataset_dir ./datasets/Dataset_Dynamic_Trend_Preserve/State/train_test/ --dataset_name increasing_early_peak_test.npy --model_dir ./experiments/DT-VAE-GAN_state_increasing_early_peak/ --diff_first_day True --model_name vae_gan_trained_model --device cuda:0
DTP_score.get_dtp_results(orig_c1_name='./datasets/Dataset_Dynamic_Trend_Preserve/State/train_test/increasing_test.npy', orig_c2_name='./datasets/Dataset_Dynamic_Trend_Preserve/State/train_test/early_peak_test.npy', gen_mix_data='./experiments/DT-VAE-GAN_state_increasing_early_peak/DT-VAE-GAN_state_increasing_early_peak.npy', dim_option=0)
# Out:
# True
# True
# True
# True
# True
# True
# ...
# args:  Namespace(batch_size=50, encoder_layer=3, decoder_layer=4, d_layer=3, hidden_dim=46, noise_dim=15, dropout=0, opt='adam', seed=7777, data_dir='./datasets/Dataset_Dynamic_Trend_Preserve/State/train_test/', data_name='state_increasing_and_early_peak', opt_scheduler='step', opt_decay_step=80, opt_decay_rate=0.8, weight_decay=0, lr=0.0015, epochs=1000, ad_loss_weight=5, experiment_name='DT-VAE-GAN_state_increasing_early_peak', parent_dir='./experiments', dis_recon_loss_weight=0.1, recon_loss_weight=1.0)
# ...
# [INFO] Using dataset: state_increasing_and_early_peak, Using device: cuda:0, Using seed: 7777
# ...
# 0, reconstruction_loss: 55.9861 kl_div: 5.3092, bce loss: 96.6770
# 1, reconstruction_loss: 52.3674 kl_div: 3.4045, bce loss: 92.5851
# 2, reconstruction_loss: 49.2945 kl_div: 2.1798, bce loss: 92.1808
# 3, reconstruction_loss: 47.2794 kl_div: 1.3207, bce loss: 92.3070
# 4, reconstruction_loss: 42.6377 kl_div: 0.7306, bce loss: 91.2665
# ...

# %%
# traffic dataset
preprocess.raw_data_loading(raw_data_dir='datasets/traffic_dataset_original/pems+sf/', option='traffic', random_state=27)
preprocess.norm_and_split_train_test(data_dir='datasets/Dataset_Dynamic_Trend_Preserve/traffic/', data_name='decreasing', save_dir='datasets/Dataset_Dynamic_Trend_Preserve/traffic/train_test/', option='traffic', norm_flag=False)
preprocess.norm_and_split_train_test(data_dir='datasets/Dataset_Dynamic_Trend_Preserve/traffic/', data_name='increasing', save_dir='datasets/Dataset_Dynamic_Trend_Preserve/traffic/train_test/', option='traffic', norm_flag=False)
preprocess.shuffle_mix_data(data_name_list=['increasing_train', 'decreasing_train'], save_dir='./datasets/Dataset_Dynamic_Trend_Preserve/traffic/train_test/', data_save_name='increasing_decreasing_train')
preprocess.shuffle_mix_data(data_name_list=['increasing_test', 'decreasing_test'], save_dir='./datasets/Dataset_Dynamic_Trend_Preserve/traffic/train_test/', data_save_name='increasing_decreasing_test')
increasing_and_decreasing_origin_test = np.load('./datasets/Dataset_Dynamic_Trend_Preserve/traffic/train_test/increasing_decreasing_test.npy')
increasing_and_decreasing_origin_train = np.load('./datasets/Dataset_Dynamic_Trend_Preserve/traffic/train_test/increasing_decreasing_train.npy')
increasing_and_decreasing_test = np.load('./datasets/Dataset_Dynamic_Trend_Preserve/traffic/train_test/increasing_decreasing_test.npy')
increasing_and_decreasing_train = np.load('./datasets/Dataset_Dynamic_Trend_Preserve/traffic/train_test/increasing_decreasing_train.npy')

# %%
# !python3 run_dvae_gan.py --data_name traffic_increasing_and_decreasing --experiment_name DT-VAE-GAN_traffic_increasing_decreasing --parent_dir ./experiments --epochs 500 --lr 0.002 --dis_recon_loss_weight 0.1 --ad_loss_weight 5 --recon_loss_weight 0.2 --data_dir ./datasets/Dataset_Dynamic_Trend_Preserve/traffic/train_test/ --hidden_dim 32 --d_layer 3 --noise_dim 15
# !python3 sample_path_generation.py --save_dir ./experiments/DT-VAE-GAN_traffic_increasing_decreasing/DT-VAE-GAN_traffic_increasing_decreasing.npy --dataset_dir ./datasets/Dataset_Dynamic_Trend_Preserve/traffic/train_test/ --dataset_name increasing_decreasing_test.npy --model_dir ./experiments/DT-VAE-GAN_traffic_increasing_decreasing/ --diff_first_day True --model_name vae_gan_trained_model --noise_dim 15 --device cuda:0
DTP_score.get_dtp_results(orig_c1_name='./datasets/Dataset_Dynamic_Trend_Preserve/traffic/train_test/increasing_test.npy', orig_c2_name='./datasets/Dataset_Dynamic_Trend_Preserve/traffic/train_test/decreasing_test.npy', gen_mix_data='./experiments/DT-VAE-GAN_traffic_increasing_decreasing/DT-VAE-GAN_traffic_increasing_decreasing.npy', dim_option='all')

# %%
# energy
